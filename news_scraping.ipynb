# %% [markdown]
# # Web Scraping

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from datetime import datetime
# Out:
# /home/peminumyakult/anaconda3/envs/suapp/lib/python3.11/site-packages/bs4/css.py:8: UserWarning: The soupsieve package is not installed. CSS selectors cannot be used.
#   warnings.warn(

# %%
def custom_strptime_detik(date_str):
    months = {
        'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04',
        'Mei': '05', 'Jun': '06', 'Jul': '07', 'Agu': '08', 'Ags': '08', 'Sep': '09', 'Okt': '10', 'Nov': '11', 'Des': '12'
    }
    date_parts = date_str.split()
    return datetime.strptime(f"{date_parts[0]} {months[date_parts[1]]} {date_parts[2]} {date_parts[3]}", '%d %m %Y %H:%M')

# %% [markdown]
# #### Detik Headlines
# Pada halaman detik, konten yang dianalisa adalah summary pada halaman headlines

# %%
def scrape_detik_headlines(query, total_pages=4):
    HEADERS = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
        'Accept-Language': 'en-US, en;q=0.5'
    }

    # Buat list untuk menyimpan data
    data = []

    base_url = f"https://www.detik.com/search/searchall?query={query}&sortby=time&page={{}}"

    for page in range(1, total_pages + 1):
        URL = base_url.format(page)
        webpage = requests.get(URL, headers=HEADERS)
        soup = BeautifulSoup(webpage.content, "lxml")
        articles = soup.find_all('article')

        for article in articles:
            link = article.find('a')['href']
            judul = article.find('h2', attrs={'class': 'title'}).string.strip()
            date = article.find('span', attrs={'class': 'date'}).get_text(strip=True)
            date = date.split(",")[1].strip()
            # Menggunakan fungsi kustom untuk mengonversi format tanggal
            date_obj = custom_strptime_detik(date)
            summary = article.find('p').string.strip()

            # Menambahkan data ke list
            data.append({"url": link, "title": judul, "date": date_obj, "summary": summary})

    # Membuat DataFrame dari list data
    df = pd.DataFrame(data)

    # Menyimpan DataFrame ke dalam file CSV (opsional)
    df.to_csv(f"{query}_headlines.csv", index=False, encoding='utf-8')

    return df

# %%
# Contoh penggunaan fungsi:
query = "kota+tasikmalaya"
total_pages = 20
df = scrape_detik_headlines(query, total_pages)
df.head()
# Out:
#                                                  url  \
# 0  https://www.detik.com/jabar/berita/d-6956616/k...
# 1  https://www.detik.com/jabar/hukum-dan-kriminal...
# 2  https://news.detik.com/berita/d-6956617/viral-...
# 3  https://www.detik.com/jabar/berita/d-6954906/v...
# 4  https://www.detik.com/jabar/hukum-dan-kriminal...
#
#                                                title                date  \
# 0  Kisah Asti Daur Ulang Sampah hingga Karyanya S... 2023-10-01 08:00:00
# 1  Jejak Kriminal Bule AS yang Tusuk Mati Mertua ... 2023-09-29 16:30:00
# 2  Viral Foto Siswa SMP di Tasik Injak Kepala Tem... 2023-09-29 16:30:00
# 3  Viral Foto Siswa SMP di Tasik Injak Kepala Tem... 2023-09-28 18:00:00
# 4  Polisi Ungkap Aplikasi Walla Pemicu Pelajar Ba... 2023-09-28 14:30:00
#
#                                              summary
# 0  Asti Gustiasih (63) tak menjadikan keterbatasa...
# 1  Arthur Leigh Welohr (35), WNA asal Amerika Ser...
# 2  Heboh video bullying siswa SMP di Cilacap, Jat...
# 3  Warga Tasikmalaya dihebohkan dengan beredarnya...
# 4  Kasus pelajar Bandung jadi korban sodomi 2 pri...

# %%
df.to_excel("data/berita_detik.xlsx", index=False)

# %% [markdown]
# #### Pikiran Rakyat Headlines

# %%
def custom_strptime_pr(date_str):
    # Mengonversi bulan ke angka
    bulan_dict = {
        "Januari": "01",
        "Februari": "02",
        "Maret": "03",
        "April": "04",
        "Mei": "05",
        "Juni": "06",
        "Juli": "07",
        "Agustus": "08",
        "September": "09",
        "Oktober": "10",
        "November": "11",
        "Desember": "12"
    }
    for bulan, angka in bulan_dict.items():
        date_str = date_str.replace(bulan, angka)

    # Mengonversi ke format datetime
    date_time_obj = datetime.strptime(date_str, "%d %m %Y, %H:%M WIB")
    return date_time_obj

# %%
from urllib.parse import urlparse, parse_qs, urlunparse
def scrape_article_content_pr(article_url):
    HEADERS = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
        'Accept-Language': 'en-US, en;q=0.5'
    }

    webpage = requests.get(article_url, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Mencari elemen konten berita yang sesuai
    article_content = soup.find('article', class_='read__content').find_all('p')

    # Mengambil teks dari elemen konten
    content_text = []
    for paragraph in article_content:
        content_text.append(paragraph.get_text(strip=True))

    # Menggabungkan semua teks konten
    article_text = ' '.join(content_text)
    print(article_text)

    # Mencari elemen paging untuk mengecek jumlah halaman
    paging_element = soup.find('div', class_='paging')
    if paging_element:
        paging_links = paging_element.find_all('a', class_='paging__link')
        num_pages = len(paging_links)
    else:
        num_pages = 1  # Jika tidak ada elemen paging, maka hanya ada satu halaman
    
    # Parse URL artikel
    parsed_url = urlparse(article_url)
    query_params = parse_qs(parsed_url.query)

    # Cek apakah ada halaman berikutnya dengan mengubah parameter page
    # dan mengambil kontennya jika ada
    page = 1
    while page <= num_pages:
        print(article_url)
        query_params['page'] = [str(page)]
        updated_url = urlunparse((
            parsed_url.scheme,
            parsed_url.netloc,
            parsed_url.path,
            parsed_url.params,
            '&'.join([f'{key}={value[0]}' for key, value in query_params.items()]),
            parsed_url.fragment
        ))
        print(updated_url)
        next_page_response = requests.get(updated_url, headers=HEADERS)
        if next_page_response.status_code == 200:
            next_page_soup = BeautifulSoup(next_page_response.content, "html.parser")
            next_article_content = next_page_soup.find('article', class_='read__content').find_all('p')
            if next_article_content:
                # Mengambil teks dari elemen konten halaman berikutnya
                next_content_text = [paragraph.get_text(strip=True) for paragraph in next_article_content]
                article_text += ' '.join(next_content_text)
                page += 1
            else:
                break
        else:
            break

    return article_text

# %%
def scrape_pr_headlines(total_pages=4):
    HEADERS = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
        'Accept-Language': 'en-US, en;q=0.5'
    }

    # Buat list untuk menyimpan data
    data = []

    base_url = f"https://www.pikiran-rakyat.com/search/?q=kota+tasikmalaya&page={{}}#gsc.tab=0&gsc.q=kota%20tasikmalaya&gsc.page=1"

    for page in range(1, total_pages + 1):
        URL = base_url.format(page)
        webpage = requests.get(URL, headers=HEADERS)
        soup = BeautifulSoup(webpage.content, "lxml")
        articles = soup.find_all('div', attrs={'class': 'latest__item'})
        
        for article in articles:
            link = article.find('a')['href']
            judul = article.find('a', attrs={'class': 'latest__link'}).string.strip()
            date_str = article.find('date', attrs={'class': 'latest__date'}).get_text(strip=True)
            # Menggunakan fungsi custom_strptime_pr untuk mengkonversi tanggal
            date = custom_strptime_pr(date_str)

            # Menggunakan fungsi scrape_article_content untuk mengambil konten berita
            article_content = scrape_article_content_pr(link)
            
            # Menambahkan data ke list
            data.append({"url": link, "title": judul, "date": date, "content": article_content})

    # Membuat DataFrame dari list data
    df = pd.DataFrame(data)
    return df

# %%
# Contoh penggunaan fungsi:
total_pages = 20
df_pr = scrape_pr_headlines(total_pages)
df_pr.head()
# Out:
#  PIKIRAN RAKYAT–Matahari Mega MallKotaTasikmalayamengalamikebakaranpada Jumat, 9 Juni 2023 siang. Momenkebakaranini beredar luas di media sosial, salah satunya dibagikan di akun Instagram @infojawabarat. Dalam video yang beredar di akun Instagram tersebut, pengunjung dan pegawai yang bekerja diMatahari Mega Mallberhamburan menyelamatkan diri. Terlihat asap tebal dan kobaran api menyelimuti swalayan besar diTasikmalayaitu. Berdasarkan informasi yang beredar,kebakarandiMatahari Mega MallTasikmalayaterjadi sekira pukul 13.57 WIB. Adapun titikkebakarandisebut terjadi di area gudang lantai dua mall tersebut. Petugas pemadamkebakaranlangsung mendatangi lokasi dan berupaya memadamkan kobaran api. Butuh waktu cukup lama untuk memadamkan kobaran api yang besar tersebut. Baca Juga:Polemik Ekspor Pasir di Indonesia, PBB Justru Serukan Aksi Lindungi Lautan Dunia Pihak kepolisian dari Polsek Cihideung PolrestaTasikmalayasudah datang untuk mengamankan lokasi. Aparat langsung mencari tahu penyebabkebakarandi pusat perbelanjaan diTasikmalayaitu. Kepala Polsek Cihideung PolrestaTasikmalayaAKP Erustiana mengungkapkan dugaan sementara terkait pemicukebakaran. Dia menjelaskan bahwakebakarandiduga terjadi akibat korsleting listri dan percikan api yang mengenai tumpukan dus di gudang bekas sepatu itu. Penyebab itu merupakan informasi dari pihak manajemenMatahari Mega MallTasikmalaya. Namun pihak kepolisian masih terus menggali informasi terkait penyebabkebakaran. Pihak manajemenMatahari Mega Malljuga belum memberikan keterangan terakit kerugian yang dialami. Pada saatkebakaranterjadi, lokasi tersebut justru dikerumuni warga yang ingin melihat kejadian tersebut.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016760531/matahari-mega-mall-kota-tasikmalaya-kebakaran-penyebab-insiden-masih-diselidiki
# https://www.pikiran-rakyat.com/jawa-barat/pr-016760531/matahari-mega-mall-kota-tasikmalaya-kebakaran-penyebab-insiden-masih-diselidiki?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016760531/matahari-mega-mall-kota-tasikmalaya-kebakaran-penyebab-insiden-masih-diselidiki
# https://www.pikiran-rakyat.com/jawa-barat/pr-016760531/matahari-mega-mall-kota-tasikmalaya-kebakaran-penyebab-insiden-masih-diselidiki?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016760531/matahari-mega-mall-kota-tasikmalaya-kebakaran-penyebab-insiden-masih-diselidiki
# https://www.pikiran-rakyat.com/jawa-barat/pr-016760531/matahari-mega-mall-kota-tasikmalaya-kebakaran-penyebab-insiden-masih-diselidiki?page=3
#  PIKIRAN RAKYAT- Kepolisian Resor KotaTasikmalayaberhasil menangkap seorang pria berinisial NR (47) yang dilaporkan melakukanperbuatan asusilaterhadap keponakannya yang merupakan siswi SMP, sejak dua tahun lalu. Pada Jumat, 2 Juni 2023, Kepala Satuan Reserse Kriminal PolresTasikmalayaKota, AKP Agung Tri Poerbowo, mengungkapkan bahwa pihak kepolisian telah berhasil mengamankan terduga pelaku setelah menerima laporan dari orangtua korban. Informasi tersebut diterima dari warga Pagerageung yang melaporkan adanya kasusperbuatan asusilayang melibatkan seorang anak perempuan yang dilakukan oleh pamannya sendiri. Agung menyebut bahwa berdasarkan pengakuan keluarga korban, tersangka telah melakukan perbuatan tersebut sejak korban berusia 11 tahun, atau sekira dua tahun yang lalu. Saat ini, korban telah berusia 13 tahun. Baca Juga:Pria di Tasikmalaya Dipolisikan Setelah 2 Tahun Cabuli Keponakan, Aksinya Tepergok Orangtua Korban “Dugaan pencabulan dilakukan pelaku (paman korban) sudah sekitar dua tahun, korban sekarang berusia 13 tahun,” ujarnya. Setelah menerima laporan itu, tim penyelidikan di bawah kepemimpinan Agung langsung melakukan investigasi yang akhirnya mengarah pada penangkapan paman korban sebagai tersangka dalam kasus asusila tersebut. Setelah penangkapan, polisi kemudian membawa tersangka ke Markas PolresTasikmalayaKota untuk dilakukan pemeriksaan hukum oleh Unit Perlindungan Perempuan dan Anak (PPA). Tim Unit PPA Satreskrim PolresTasikmalayaKota terus melakukan pemeriksaan yang lebih mendalam terhadap tersangka.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016734033/polisi-tangkap-pria-yang-mencabuli-keponakannya-di-tasikmalaya-pelaku-diduga-sudah-2-tahun-lakukan-aksinya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016734033/polisi-tangkap-pria-yang-mencabuli-keponakannya-di-tasikmalaya-pelaku-diduga-sudah-2-tahun-lakukan-aksinya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016734033/polisi-tangkap-pria-yang-mencabuli-keponakannya-di-tasikmalaya-pelaku-diduga-sudah-2-tahun-lakukan-aksinya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016734033/polisi-tangkap-pria-yang-mencabuli-keponakannya-di-tasikmalaya-pelaku-diduga-sudah-2-tahun-lakukan-aksinya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016734033/polisi-tangkap-pria-yang-mencabuli-keponakannya-di-tasikmalaya-pelaku-diduga-sudah-2-tahun-lakukan-aksinya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016734033/polisi-tangkap-pria-yang-mencabuli-keponakannya-di-tasikmalaya-pelaku-diduga-sudah-2-tahun-lakukan-aksinya?page=3
# PIKIRAN RAKYAT -Komisi Perlindungan Anak Indonesia Daerah (KPAID)Kota Tasikmalaya, telah menemui siswa sebuah SMA Negeri diKota Tasikmalaya, Jawa Barat, yang diduga jadi korban pemukulananak pejabat. KPAIDKota Tasikmalayajuga langsung melakukan asesmen dan pendampingan terhadap korban, setelah membaca curhat ibu sang korban di media sosial. Ketua KPAIDKota Tasikmalaya, Rina mengatakan, setelah mendapatkan informasi yang viral di media sosial tentang dugaan kekerasan terhadap siswi SMA olehanak pejabat, pihaknya langsung melakukan kontak dengan korban. Baca Juga:Siswa SMA di Tasikmalaya Diduga Dipukul Anak Pejabat, Kondisinya Malah Drop Usai Mediasi “Kami telah melakukan kontak dengan korban dan akan melakukan asesmen serta melakukan pendampingan terhadap korban,” kata Rina, dilansir Kabar Priangan, Senin, 22 Mei 2023. Pihak sekolah pun menggelar mediasi mempertemukan korban yang merupakan pelajar perempuan, dengan pihak terlapor, pelajar pria bernama Ar. Namun, menurut Joeliana, ibu korban, anaknya malah mengedrop usai pertemuan tersebut lantaran adanyaintimidasi. Hal itu diungkapkan Joeliana, setelah ia pun mengunggah foto luka di bagian pelipis mata sebelah kiri siswi tersebut, dan luka lebam pada tiga titik bagian tubuhnya. "Dan keheranan saya terjawab hari ini, anak saya dipanggil ke ruangan guru oleh pihak sekolah dan orangtua pelaku. Menurut saya pertemuan hari ini sudah tidak fair, pelaku (ortu) vs korban (anak),”ujarnya dalam unggahan di Instagram, Minggu, 21 Mei 2023. Unggahan orangtua korban di media sosial tentang kasus kekerasan yang dialami putrinya di salah satu SMA negeri di Kota Tasikmalaya.*/kolase kabar-priangan.com/Instagram/@uyung_ariaJoeliana mengaku mengetahui isi percakapan selama mediasi dari rekaman suara. Apa isi rekaman suara itu sehingga anaknya mengalami kondisi yang melemah?
# https://www.pikiran-rakyat.com/jawa-barat/pr-016688751/isi-rekaman-mediasi-siswa-sma-tasikmalaya-dengan-anak-pejabat-disorot-orangtua-ada-intimidasi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016688751/isi-rekaman-mediasi-siswa-sma-tasikmalaya-dengan-anak-pejabat-disorot-orangtua-ada-intimidasi?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016688751/isi-rekaman-mediasi-siswa-sma-tasikmalaya-dengan-anak-pejabat-disorot-orangtua-ada-intimidasi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016688751/isi-rekaman-mediasi-siswa-sma-tasikmalaya-dengan-anak-pejabat-disorot-orangtua-ada-intimidasi?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016688751/isi-rekaman-mediasi-siswa-sma-tasikmalaya-dengan-anak-pejabat-disorot-orangtua-ada-intimidasi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016688751/isi-rekaman-mediasi-siswa-sma-tasikmalaya-dengan-anak-pejabat-disorot-orangtua-ada-intimidasi?page=3
#  PIKIRAN RAKYAT- Kondisi sejumlah ruasjalandi wilayah KotaTasikmalayasudah sangat menghawatirkan. Kerusakan tersebut akibat sudah lama tidak ada perbaikan. Salah satunya terlihat di sekitaran Pasar Cikurubuk, Kecamatan Mangkubumi, KotaTasikmalaya. Saat hujan turun, apalagi dengan intensitas tinggi, dipastikan ada genangan-genangan air dalam yang mengganggu aktivitas warga, khususnya para pengendara. Salah seorang pedagang kaki lima yang berjualan di Blok A2 Pasar Cikurubuk, Lili Suherli (49) membenarkan hal tersebut. Dia membeberkan kondisi hujan dijalanlintas Cikurubuk kerap mengakibatkan genangan air karena banyaknyajalanyang berlobang. Selain menimbulkanjalanmenjadi becek, genangan tersebut juga cukup merepotkan penggunajalan. Baca Juga:Jokowi Turun Tangan Soal Jalan Rusak di Jambi, Ungkap Waktu Perbaikan "Dengan kondisijalanseperti ini tak sedikit penggunajalanyang hampir celaka khususnya pengguna sepeda motor karena lobangnya cukup dalam," katanya. Terkait kondisijalanrusak yang ada di wilayah KotaTasikmalaya, Pemerintah KotaTasikmalayasudah melakukan inpentarisir. "Pak wali sudah minta kepada Dinas PU di bawah kordinir Asda 2 untuk menginpentarisir kondisijalandi Kota Tasik karena kelihatannya memang banyak yang sudah memerlukan perbaikan, termasuk yang di Pasar Cikurubuk," ujar Sekretaris Derah PemkotTasikmalayaIvan Dicksan kepada wartawan usai kegiatan simulasi penangulangan bencana pada Selasa, 16 Mei 2023. Baca Juga:Jalan Rusak Akibat Bencana Alam di Kuningan yang Tak Miliki Alternatif Mulai Diperbaiki
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016667584/jalan-rusak-warga-keluhkan-genangan-air-di-pasar-cikurubuk-tasikmalaya?page=4
#  PIKIRANRAKYAT- Angka cakupan pencapaian pelaksanaanvaksinpolio putaran pertama di Kota Tasikmalaya  mencapai 97,6 persen. Sehingga dengan pencapaian vaksinasi 97,6, tersebut, Kota Tasik berada di 10 besar capaian vaksinasi polio tahap pertama tertinggi di Jawa Barat. Pernyataan tersebut disampaikan Kepala Bidang Kepala Bidang Pencegahan dan Pengendalian Penyakit Dinas Kesehatan Kota Tasikmalaya Asep Hendra pada Minggu, 14 Mei 2023. Adapun kata dia, rata-rata pencapaianvaksinpolio tahap pertama di Jawa Barat mancakup 27 daerah kota dan kabupaten pencapaiannya 92,6 persen. Selain Kota Tasik lanjut dia, ada 17 kota dan kabupaten di Jawa Barat yang capaian vaksinasi polio tahap pertamanya di atas 95 persen. Baca Juga:Pastikan Puluhan Ribu Balita Imunisasi Polio Kedua, Bupati Purwakarta Siagakan Ribuan Pos Kesehatan "Nah untuk yang pencapaiannya diatas  95 persen, pelaksanaan paksin putaran kedua polio secara serentak akan dilaksanakan mulai Senin, 15 Mei 2022. Dan sisanya kemungkinan di tanggal 22 Mei 2023 termasuk Kota Tasikmalaya," jelas Asep. Walupun kata Asep, masih ada sisa sekitaar 2,3 persen, pelaksanaan vaksinasi volio tahap kedua tetap besok melaksanakanvaksinputaran dua. Di Jawa Barat sendiri ujar Asep, hanya saja ada empat daerah yang tidak melaksanakan vaksinasi polio tahap kedua secara langsung senin besok dikarenakan capaian vaksinasi polio tahap pertama di empat daerah tersebut masih dibawah 90 persen. "Jadi untuk daerah yang capaiannya kurang dari 90 persen kemungkinan besar pelaksanaanvaksinpolio tahap keduanya di Bulan Juli 2023," ujarnya. Baca Juga:Imunisasi Polio di Purwakarta Lampaui Target Meski Masih Ada Masyarakat yang Menolak Diimunisasi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016661415/kota-tasikmalaya-masuk-10-besar-pencapaian-vaksin-polio-putaran-pertama-di-jawa-barat
# https://www.pikiran-rakyat.com/jawa-barat/pr-016661415/kota-tasikmalaya-masuk-10-besar-pencapaian-vaksin-polio-putaran-pertama-di-jawa-barat?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016661415/kota-tasikmalaya-masuk-10-besar-pencapaian-vaksin-polio-putaran-pertama-di-jawa-barat
# https://www.pikiran-rakyat.com/jawa-barat/pr-016661415/kota-tasikmalaya-masuk-10-besar-pencapaian-vaksin-polio-putaran-pertama-di-jawa-barat?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016661415/kota-tasikmalaya-masuk-10-besar-pencapaian-vaksin-polio-putaran-pertama-di-jawa-barat
# https://www.pikiran-rakyat.com/jawa-barat/pr-016661415/kota-tasikmalaya-masuk-10-besar-pencapaian-vaksin-polio-putaran-pertama-di-jawa-barat?page=3
# PIKIRAN RAKYAT- Polemik pembangunanGedung Creative Center(GCC) Dadaha di KotaTasikmalayayang sempat menjadi objek pemeriksaan Badan Pemeriksa Keuangan (BPK) mendapat sorotan berbagai pihak. Terkait itu, Wakil Gubernur Jawa Barat Uu Ruzhanul Ulum langsung mengunjungi GCC pada Jumat, 12 Mei 2023. Hanya saja, Uu RUzhanul Ulum tidak secara spesifik melakukan pemeriksaan GCC, walaupunsalah satu permasalahan yang sangat menjadi sorotan adalah dugaan penggunaanliftbekas di gedung tersebut. Uu tidak sampai masuk ke gedung guna memeriksa kondisilift. Dirinya hanya berada di luar gedung dan berbincang dengan Pj. Wali KotaTasikmalayaCheka Virgowansyah yang mendampinginya. Bahkan, saat diwawancara wartawan, Uu juga tidak bicara banyak bicara dan hanya menjelaskan kedatangannya ke GCC Dadaha atas perintah Gubernur Jawa Barat Ridwan Kamil. "Nanti wawancaranya ke Pak Wali saja. Pada prinsipnya, saya datang ke sini atas tugas dari Pak Gubernur," ujar Uu. Baca Juga:Manajer yang Ajak Karyawati di Bekasi Staycation Dipecat, Proses Hukum Tetap Berlanjut Di tempat yang sama, Pj. Wali KotaTasikmalayaCheka Virgowansyah menjelaskan terkait tindak lanjut hasil pemeriksaan BPK. Cheka mengatakan, PemkotTasikmalayaakan menunggu hasil pembahasan Pansus LHP BPK di DPRD KotaTasikmalaya. "Untuk kasus ini dewan sudah membentuk Pansus. Karena proses ini sudah bergulir, kita tunggu hasil Pansus dulu. LHP kan sama Pansus sedang dikaji oleh dewan. Nanti kita tunggu hasilnya saja," sebut Cheka. Cheka menjelaskan, rekomendasi yang diberikan BPK dan hasil pembahasan Pansus DPRD berjalan secara bersamaan sehingga nanti tindak lanjut dari temuan-temuan BPK bisa dituntaskan. "Rekomendasi yang diberikan BPK dan Pansus berjalan simultan, nanti kita tunggu hasilnya. Pembahasan Pansus kan terbuka, kita ikuti saja," ujar Cheka. Terkait temuan dugaan pemakaianliftbekas dalam pembangunan GCC, Cheka mengaku penanganan akan dilakukan Dinas PUTR KotaTasikmalaya. "Karena secara teknis yang mengurus itu adalah Dinas PUTR," katanya.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016654300/wagub-jawa-barat-tinjau-gedung-creative-center-tasikmalaya-yang-diduga-pakai-lift-bekas
# https://www.pikiran-rakyat.com/jawa-barat/pr-016654300/wagub-jawa-barat-tinjau-gedung-creative-center-tasikmalaya-yang-diduga-pakai-lift-bekas?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016654300/wagub-jawa-barat-tinjau-gedung-creative-center-tasikmalaya-yang-diduga-pakai-lift-bekas
# https://www.pikiran-rakyat.com/jawa-barat/pr-016654300/wagub-jawa-barat-tinjau-gedung-creative-center-tasikmalaya-yang-diduga-pakai-lift-bekas?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016654300/wagub-jawa-barat-tinjau-gedung-creative-center-tasikmalaya-yang-diduga-pakai-lift-bekas
# https://www.pikiran-rakyat.com/jawa-barat/pr-016654300/wagub-jawa-barat-tinjau-gedung-creative-center-tasikmalaya-yang-diduga-pakai-lift-bekas?page=3
#  PIKIRAN RAKYAT- Komisi Pemilihan Umum (KPU) Kota Tasikmalaya kembali membuka pengajuan bakal calon anggota DPRD Kota Tasikmalaya bertempat di Kantor KPU Kota Tasikmalaya pada Kamis, 11 Mei 2023. Pada jadwal pengajuan bakal calon anggota DPRD Kota Tasikmalaya tersebut, Kantor KPU Kota Tasikmalaya kedatangan 3 partai pesertaPileg 2024untuk mendaftarkan bakal calonnya. Ketiga partai tersebut yakni Partai Demokrasi Indonesia Pembangunan (PDIP), Partai Nasdem, dan Partai Persatuan Pembangunan (PPP). Kedatangan ketiga partai peserta Pileg DPRD Kota Tasik tersebut diterima langsung Ketua Komisi Pemilihan Umum (KPU) Kota Tasikmalaya Ade Zaenul Mutqim, Komisioner KPU Bambang Setyawan dan jajaran KPU Kota Tasik. Baca Juga:Viral Ketua RT Cekcok dengan Pemilik Ruko di Jakarta Utara, Terungkap Penyebabnya Adapun partai PDI Perjuangan merupakan partai yang pertama kali datang ke KPU. Dipimpin langsung Ketua DPCPDIPKota Tasik Muslim, pada kegiatan tersebutPDIPmendaftarkan bakal calon-nya sebanyak 45 bakal calon atau 100 persen dari kuota bakal calon yang telah ditentukan. Ketua DPCPDIPKota Tasik Muslim mengatakan bahwa untukPileg 2024nanti, kita memasang target 11 kursi di DPRD Kota Tasikmalaya. Selain sumber daya manusia yang mumpuni, Muslim juga cukup yakin dapat efek ekor jas dari pencapresan Ganjar Pranowo. "Ya kita sangat optimistis dengan target tersebut karena alhamdulillah kita memiliki caleg yang mumpuni dan InsyaAllah bisa diterima masyarakat," ujar Muslim. Ketua KPU Kota Tasikmalaya Ade Zaenul mengalungkan kain batik kepada salah satu pimpinan partai yang mendaftarkan bacalegnya di Kantor KPU Kota Tasikmalaya pada Kamis, 11 Mei 2023.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016650153/pileg-2024-tiga-partai-besar-mendaftar-ke-kpu-tasikmalaya?page=4
#  PIKIRAN RAKYAT- Keberadaan pesawat F-5 Tiger milik TNI AU yang telah terparkir di Taman KotaTasikmalayasejak beberapa waktu lalu terus disempurnakan. Keberadaanmonumensejarah tersebut kini menjadi perhatian publik dan menjadi daya tarik warga masyarakat tidak hanya dari KotaTasikmalaya, tetapi juga dari KabupatenTasikmalayadan beberapa daerah lainnya sebagai salah satu tempat wisata. Saat ini, pesawat F-5 Milik TNI AU bernomor LM 2617 itu telah berdiri tegak di tiang pancang dengan tiga rodanya. Lokasi Pesawat F-5 tersebut masih dalam tahap penyempurnaan oleh pihak CV Pusaka yang kini sedang melakukan pengerjaan anak tangga dan tiang penghalang pesawat. Dadih (49), salah seorang pekerja pembangunanmonumensaat ditemui di lokasi pada Selasa, 9 Mei 2023 mengatakan, kini pengerjaanmonumenbaru di taman kota tersebut sudah masuk tahapfinishing,seperti merapikan tiang dengan plesteran semen serta pembuatan anak tangga dan pagar untuk pesawat. “Karena kalau tidak dibuatkan seperti itu, nantinya para pengunjung yang datang dikhawatirkan tidak hanya melihat untuk berswafoto akan tetapi bisa memanjat pesawat dan ini sangat berbahaya,” katanya. Baca Juga:Jembatan Cidugaleun di Tasikmalaya Ambruk, Jalan Darurat Pengganti Tetap Berisiko Dadih mengatakan, pengerjaan penyempurnaan lokasimonumensudah sekira 80 persen. “Yah sudah hampir selesai sekitar 80 persen lah, dua minggu lagi juga selesai," katanya. "Kalau udah selesai dikerjakan pihak pemerintah KotaTasikmalayatinggal meresmikanmonumenpesawat ini,” ucapnya menambahkan. Sebelumnya, Pj. Wali KotaTasikmalaya, Cheka Virgowansyah mengatakan menumen Pesawat F-5 Tiger milik TNI AU telah terparkir di Taman Kota Jalan HZ Mustofa KotaTasikmalayasejak awal Mei 2023 dan tinggal menunggu penyelesaian pengerjaan.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016642634/bikin-kaget-ada-monumen-pesawat-tiger-f-5-di-taman-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016642634/bikin-kaget-ada-monumen-pesawat-tiger-f-5-di-taman-kota-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016642634/bikin-kaget-ada-monumen-pesawat-tiger-f-5-di-taman-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016642634/bikin-kaget-ada-monumen-pesawat-tiger-f-5-di-taman-kota-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016642634/bikin-kaget-ada-monumen-pesawat-tiger-f-5-di-taman-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016642634/bikin-kaget-ada-monumen-pesawat-tiger-f-5-di-taman-kota-tasikmalaya?page=3
#  PIKIRANRAKYAT- Khawatir munculnya kriminalisasi di dunia kesehatan, ratusan tenaga kesehatan di KotaTasikmalayamelakukan aksi unjuk rasa menolak Rancangan Undang-undang (RUU)Omnibus LawKesehatan yang tengah dibahas pemerintah pusat dan DPRD pada Senin, 8 Mei 2023. Demonstrasi berupa aksi damai dan aksi simpatik yang diisi dengan pernyataan sikap yang ditandai penandatanganan kesepahaman bersama tersebut, digelar di halaman Sekretarist Ikatan Dokter Indonesia (IDI) Kota Komplek Perkantoran TIP Jalan HZ, Kecamatan Tawang, KotaTasikmalaya. Ratusan pengurus dan anggota lima organisasi profesi tenaga kesehatanTasikmalaya, yang masing-masing dari Ikatan Dokter Indonesia (IDI) Kota Tasik, Ikatan Bidan Indonesia, (IBI) Persatuan Dokter Gigi Indonesia (PDGI), Ikatan Apoteker Indonesia (IAI) serta Persatuan Perawat Nasional Indonesia (PPNI) menggenakan pita hitam sebagai bentuk keprihatinan atas situasi di dunia kesehatan yang terjadi saat ini. Baca Juga:Nakes Berencana Mogok Kerja Protes RUU Kesehatan, Kemenkes Singgung Sumpah Profesi Banyaknya pasal dalam RUU yang menyebutkan akan menghapuskan seluruh organisasi profesi kesehatan menjadi salah satu pemicu aksi yang dilakukan para praktisi kesehatan tersebut. Koordinator aksi yang juga Ketua Umum IDI KotaTasikmalayaDr Polar Silomi S.Pog mengatakan, RUUOmnibus LawKesehatan dinilai akan memecah belah profesi medis dan merugikan setiap tenaga kesehatan. Padahal fungsi organisasi profesi selama ini telah sangat membantu pemerintah mulai pengawasan etik, kompetensi dan lainnya. "Kami khawatir kalau tidak ada organisasi, Dinkes di seluruh daerah dimungkinkan kesulitan meng-handlesemua itu. Belum lagi ke depannya akan muncul organisasi buram kesehatan yang tak jelas," katanya. Baca Juga:Dokter yang Dipecat RS Kariadi Semarang Dukung Nakes Demo Tolak RUU Kesehatan, Singgung Kisah Nabi Ibrahim Selain itu, kata dia, dalam RUU tersebut banyak pasal yang memgarah pada tindakan kriminalisasi profesi dunia kesehatan dilihat dari isi per pasal yang dimilai akan sangat memberatkan semua.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016640304/ratusan-tenaga-kesehatan-di-tasikmalaya-unjuk-rasa-tolak-ruu-ominbus-law-kesehatan
# https://www.pikiran-rakyat.com/jawa-barat/pr-016640304/ratusan-tenaga-kesehatan-di-tasikmalaya-unjuk-rasa-tolak-ruu-ominbus-law-kesehatan?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016640304/ratusan-tenaga-kesehatan-di-tasikmalaya-unjuk-rasa-tolak-ruu-ominbus-law-kesehatan
# https://www.pikiran-rakyat.com/jawa-barat/pr-016640304/ratusan-tenaga-kesehatan-di-tasikmalaya-unjuk-rasa-tolak-ruu-ominbus-law-kesehatan?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016640304/ratusan-tenaga-kesehatan-di-tasikmalaya-unjuk-rasa-tolak-ruu-ominbus-law-kesehatan
# https://www.pikiran-rakyat.com/jawa-barat/pr-016640304/ratusan-tenaga-kesehatan-di-tasikmalaya-unjuk-rasa-tolak-ruu-ominbus-law-kesehatan?page=3
#  PIKIRAN RAKYAT- Usai musimLebaran 2023, kasus terkonfirmasi positif Covid-19 kembali mengalami peningkatan. Mobilisasi masyarakat saat musim lebaran dengan banyaknya warga luar kota yang datang ke KotaTasikmalaya, disinyalir menjadi penyebab terjadinya peningkatan kasus Covid-19. Kepala Bidang Pencegahan dan Pengendalian Penyakit Dinas Kesehatan KotaTasikmalayaAsep Hendra membenarkan bahwa penyebaran kasus Covid-19 di daerah tersebut saat ini kembali mengalami peningkatan. Di KotaTasikmalaya, kata Asep, saat ini hampir 50 orang pasien terkonfirmasi positif Covid-19. "Mereka saat ini dirawat di ruang isolasi RSUD dr. Soekardjo sebanyak 37 pasien, satu pasien di RS TMC, dua pasien di RS Jasa Kartini, dan dua orang meninggal dunia," katanya. Baca Juga:Roundup: WHO Hapus Status Darurat Kesehatan Global untuk Covid-19 Peningkatan kasus Covid-19 yang terjadi saat ini, kata Asep, bisa dikatakan sangat signifikan karena sebelumnya atau sejak pandemi melandai, kasus yang dilaporkan tidak pernah lebih dari 10 kasus. Menurutnya, peningkatan penyebaran kasus Covid-19 di KotaTasikmalayamungkin akibat mobilisasi masyarakat pada saat musimLebaran 2023yang sangat tinggi. “Kita tahu kan selama musim lebaran kemarin di Kota Tasik jalan-jalan di pusat kota tiap hari macet. Juga terjadi kerumunan-kerumunan di sejumlah pusat perbelanjaan, apalagi yang berkerumun itu banyak warga luar yang baru datang ke Kota Tasik," ujarnya menerangkan. Lebih lanjut, peningkatan kasus Covid-19 saat ini karena ada jenis mutasi varian baru, yakni Arcturus, sehingga menyebabkan kasus Covid-19 juga meningkat secara nasional.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016635292/kasus-covid-19-di-tasikmalaya-meningkat-usai-lebaran-2023-dinkes-ungkap-penyebabnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016635292/kasus-covid-19-di-tasikmalaya-meningkat-usai-lebaran-2023-dinkes-ungkap-penyebabnya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016635292/kasus-covid-19-di-tasikmalaya-meningkat-usai-lebaran-2023-dinkes-ungkap-penyebabnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016635292/kasus-covid-19-di-tasikmalaya-meningkat-usai-lebaran-2023-dinkes-ungkap-penyebabnya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016635292/kasus-covid-19-di-tasikmalaya-meningkat-usai-lebaran-2023-dinkes-ungkap-penyebabnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016635292/kasus-covid-19-di-tasikmalaya-meningkat-usai-lebaran-2023-dinkes-ungkap-penyebabnya?page=3
#  PIKIRANRAKYAT- Kekurangan tenaga pendidik atauguruselama ini dinilai masih menjadi kendala dalam memajukan pendidikan di KotaTasikmalaya. Saat ini, KotaTasikmalayakekurangangurucukup banyak, sekitar 400-anguruuntuk jenjang sekolah dasar dan menengah. Pernyataan tersebut disampaikan Pj WalikotaTasikmalayaCheka Virgowansyah pada Rabu, 3 Mei 2023. Menurut Cheka, kekurangan tenagagurudi kotanya akibat keterbatasan anggaran di Pemerintah Kota (Pemkot)Tasikmalayayang tidak memungkinkan untuk mengangkat pegawai guna menutupi kekurangangurutersebut. Baca Juga:Komisi II DPR: Seluruh Tenaga Honorer Akan Diangkat Menjadi PPPK Tanpa Ada Pengecualian "Ya anggaran yang di kita kan terbatas, sehingga untuk mengangkat pegawai sebanyak kebutuhan itu memang cukup berat," ujar Cheka. Namun demikian, lanjut dia, pihaknya akan kita terus mencoba mengusulkan pengangkatan pegawai untuk menutupi kebutuhan tersebut. "Kita akan mengusulkan formasi PPPK untukguruini lebih banyak. Karena kita ingin anak didik kita terlayani." "Pengusulan PPPK untuk tenaga pengajar insya allah menjadi prioritas," ujar Cheka menambahkan.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016626286/akibat-keterbatasan-anggaran-tasikmalaya-kekurangan-400-guru-untuk-jenjang-sekolah-dasar-dan-menengah
# https://www.pikiran-rakyat.com/jawa-barat/pr-016626286/akibat-keterbatasan-anggaran-tasikmalaya-kekurangan-400-guru-untuk-jenjang-sekolah-dasar-dan-menengah?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016626286/akibat-keterbatasan-anggaran-tasikmalaya-kekurangan-400-guru-untuk-jenjang-sekolah-dasar-dan-menengah
# https://www.pikiran-rakyat.com/jawa-barat/pr-016626286/akibat-keterbatasan-anggaran-tasikmalaya-kekurangan-400-guru-untuk-jenjang-sekolah-dasar-dan-menengah?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016626286/akibat-keterbatasan-anggaran-tasikmalaya-kekurangan-400-guru-untuk-jenjang-sekolah-dasar-dan-menengah
# https://www.pikiran-rakyat.com/jawa-barat/pr-016626286/akibat-keterbatasan-anggaran-tasikmalaya-kekurangan-400-guru-untuk-jenjang-sekolah-dasar-dan-menengah?page=3
#  PIKIRAN RAKYAT- Dianggap belum menuntaskan sejumlah masalah,Dinas Pendidikan(Disdik) KotaTasikmalayadidemo sekelompok pemuda yang mengatasnamakan Ikatan Pemuda Nahdatul Ulama (IPNU) KotaTasikmalayapada momentumHari Pendidikan Nasional, Selasa, 2 Mei 2023. Dalam aksi tersebut, puluhan pemuda mendatangi KantorDinas PendidikanKotaTasikmalayayang berada di Komplek Perkantoran Jalan IR. Handa pukul 10:00 WIB. Mereka membawa spanduk bertuliskan "Hilangkan Pungli Naik Ggolongan" di lingkungan Disdik KotaTasikmalaya. Perwakilan massa aksi secara bergantian melakukan orasi menuntutDinas PendidikanKotaTasikmalayabekerja secara profesional, memiliki program yang jelas, dan menghilangkan tindakan-tindakan yang melanggar aturan. Baca Juga:Peringati Hardiknas 2023, Nadiem Sebut Merdeka Belajar Jadi Jalan Wujudkan Cita-cita Luhur Ki Hadjar Dewantara Massa aksi juga sempat membakar ban bekas dan meminta agar KepalaDinas PendidikanKotaTasikmalayaEli Suminar datang menemui mereka. Dengan pengawalan yang ketat dari petugas kepolisian, Eli bersedia mendatangi massa aksi dan melakukan dialog. Fikri Nur Padilah selaku koordinator lapangan mengatakan, aksi tersebut dilakukan atas banyaknya permasalahan-permasalahan diDinas Pendidikansetempat yang dinilai tidak kunjung terselesaikan di bawah kepemimpinan kepalanya saat ini. "Ya kami mendapat banyak pengaduan dari masyarakat khususnya peserta didik atau para pelajar yang merasa resah denga kebijakan-kebijakan yang sikeluarkanDinas Pendidikan," ujar Fikri usai melakukan aksi kepada wartawan, Selasa, 2 Mei 2023. Baca Juga:Ada 130 Kecamatan di Jabar Belum Punya SMA/SMK, Pemprov Prioritaskan 33 Kecamatan Dulu Beberapa di antaranya; banyak anak yang putus sekolah karena kurang mendapat perhatian di bidang pendidikan hingga banyak kebijakan yang tidak jelas yang dikeluarkanDinas Pendidikan.
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo?page=1
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo?page=2
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo?page=3
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo
# https://www.pikiran-rakyat.com/pendidikan/pr-016618585/momentum-hari-pendidikan-nasional-dinas-pendidikan-tasikmalaya-didemo?page=4
#  PIKIRAN RAKYAT- Enam haripascalebaran2023/1444 H, harga-harga bahan pokokdi sejumlah pasar di KotaTasikmalayamulai mengalami penurunan. Berdasarkan pantauan di beberapa pasar tradisional yang ada di KotaTasikmalaya, pada Jumat, 28 April 2023, setelah mengalami kenaikan yang cukup tinggi selama musim Lebaran,harga bahan pokokberangsur turun walaupun belum semuanya kembali ke harga semula. Menurut sebagian pedagang di Pasar Cikurubuk, kenaikan bahan pokok  sudah biasa terjadi ketika memasuki H-3 Lebaran hingga H+4 Lebaran. Sedangkan setelah melewati H+4 setelah Lebaran, harga-harga bahan pokokbiasanya akan turun hingga kembali ke harga normal. Baca Juga:Mobil Tabrak Motor hingga Nyungsep ke Pekarangan Rumah Warga di Tasikmalaya Saat ini, penurunan harga salah satunya mulai memengaruhi harga daging sapi, daging ayam kampung, ayam sayur, dan beberapa jenis sayuran. Harga daging sapi yang pada musim Lebaran sempat menembus angka Rp150.000 hingga Rp160.000 per kg, kini berkisar Rp135.000 hingga 140.000 per kg. H. Popon, salah seorang penjual daging sapi di Pasar Cikurubuk membenarkan informasi tersebut. "Ramainya permintaan daging oleh masyarakat selama musim Lebaran biasanya tidak lebih dari satu minggu yaitu mulai H-2 Lebaran hingga H+4 Lebaran. Nah setelah itu biasanya pembeli mulai berkurang dan harga daging pun biasanya mulai turun kembali," ujar Popon. Baca Juga:Viral Pengemis di Bogor Bawa Uang Jutaan Rupiah, Cek Rp1,3 Miliar, dan STNK Motor Selain daging sapi, penurunan harga juga terjadi pada harga daging ayam kampung dan ayam sayur. Harga ayam kampung yang pada musim Lebaran  mencapai Rp75.000 per kg, kini turun menjadi Rp65.000 per kg. Sedangkan ayam sayur yang sempat mencapai Rp45.000 per kg, kini mulai turun menjadi Rp35.000 per kg.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016603819/6-hari-pascalebaran-harga-bahan-pokok-di-tasikmalaya-berangsur-turun
# https://www.pikiran-rakyat.com/jawa-barat/pr-016603819/6-hari-pascalebaran-harga-bahan-pokok-di-tasikmalaya-berangsur-turun?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016603819/6-hari-pascalebaran-harga-bahan-pokok-di-tasikmalaya-berangsur-turun
# https://www.pikiran-rakyat.com/jawa-barat/pr-016603819/6-hari-pascalebaran-harga-bahan-pokok-di-tasikmalaya-berangsur-turun?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016603819/6-hari-pascalebaran-harga-bahan-pokok-di-tasikmalaya-berangsur-turun
# https://www.pikiran-rakyat.com/jawa-barat/pr-016603819/6-hari-pascalebaran-harga-bahan-pokok-di-tasikmalaya-berangsur-turun?page=3
#  PIKIRAN RAKYAT- Selama masa libur Lebaran 2023 atau H-1 hingga H+5 lebaran, debitsampahdi KotaTasikmalayadiperkirakan bertambah 30 hingga 50 persen dibanding hari-hari biasa. Tumpukan-tumpukansampahterlihat hampir di trotoar ruas-ruas jalan yang ada di KotaTasikmalaya. Mulai dari jalan Bantarsari, Perintis Kemerdekaan, Empangsari, Paseh, Gunung Sabeulah, Ampera, Simpang Lima, Buninagara, RE Martadinata, Ahmad Yani, dan sejumlah ruas jalan lainnya dipenuhisampah. Tumpukansampahdidominasisampahrumah tangga seperti plastik, bekas ketupat, barang pecah, dan sisa-sisa makanan khas Lebaran. Baca Juga:Libur Lebaran 2023, Okupansi Hotel dan Kunjungan ke Wisata Jawa Barat Naik Sampah-sampahtersebut diduga sengaja dibuang warga di sembarang tempat karena tempatsampahdi rumah mereka sudah penuh. Akibatnya, bau tidak mengganggu warga sekitar. "Maklum, di rumah tongsampahkami sudah penuh. Daripada menimbulkan bau tidak sedap, lebih baik kami buang ke sini aja," ujar Dian, warga Jl. Ikik Wiradikarta (Kalektoran), KotaTasikmalaya. Dian mengaku, selain menimbulkan bau yang tidak sedap, ia hawatir tumpukansampahyang terus dibiarkan akan menimbulkan penyakit. "Lihat saja Lalat-lalat diatas tumpukansampahtersebut sangat banyak, bisa saja lalat tersebut terbang kerumah dan membawa sumber penyakit," katanya. Baca Juga:Polisi Ringkus Komplotan Pungli Berkedok Retribusi di Sejumlah Wisata Sukabumi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016597089/selama-lebaran-2023-debit-sampah-di-tasikmalaya-bertambah-hingga-50-persen
# https://www.pikiran-rakyat.com/jawa-barat/pr-016597089/selama-lebaran-2023-debit-sampah-di-tasikmalaya-bertambah-hingga-50-persen?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016597089/selama-lebaran-2023-debit-sampah-di-tasikmalaya-bertambah-hingga-50-persen
# https://www.pikiran-rakyat.com/jawa-barat/pr-016597089/selama-lebaran-2023-debit-sampah-di-tasikmalaya-bertambah-hingga-50-persen?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016597089/selama-lebaran-2023-debit-sampah-di-tasikmalaya-bertambah-hingga-50-persen
# https://www.pikiran-rakyat.com/jawa-barat/pr-016597089/selama-lebaran-2023-debit-sampah-di-tasikmalaya-bertambah-hingga-50-persen?page=3
#  PIKIRAN RAKYAT- Aparatur Sipil Negara (ASN) di lingkungan PemkotTasikmalayadiminta berprilaku disiplin atau masuk kerja, Rabu, 26 April 2023 setelah libur Idul Fitri 1444 Hijriah. Penegasan tersebut disampaikan PjWali KotaTasikmalayaCheka Virgowansyah pada Selasa, 25 April 2023. “Kita sudah ingatkan seluruh pegawai agar sudah mulai masuk kerja pada hari Rabu," ujarnya. Cheka menegaskan, tidak ada alasanASNuntuk menambah libur setelah masalibur Lebaran2023. Pasalnya, libur Idul Fitri 1444 H sudah ditentukan. Baca Juga:Macet di Puncak Bogor Disebut Horor, Lalu Lintas Kendaraan Capai 160 Ribu dalam Semalam “Sesuai surat edaran yang dikeluarkan pemerintah,ASNtidak dibenarkan menambah libur di luar aturan yang sudah ditentukan,” kata Cheka. Jika masih adaASNyang melanggar ketentuan, maka akan diberi sanksi disiplin. Kecuali sakit itupun harus benar-benar ada surat dari dokter. “Sanksi yang diberikan sesuai dengan PP 53 dan PP 94 tentang disiplin Pegawai Negeri," katanya. Baca Juga:Produksi Sampah di Objek Wisata Pangandaran Capai Sekitar 150 Ton Per Hari Saat Liburan Lebaran 2023 Cheka juga menambahkan, jam kerjaASNsetelah libur lebaran ada perubahan hari dan jam operasional kerja yang diberlakukan bagi instansi pemerintah. Ketentuan tersebut sesuai dengan Peraturan Presiden (Perpres) nomor 21 tahun 2023.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016593455/wali-kota-tasikmalaya-asn-yang-tambah-libur-lebaran-2023-akan-disanksi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016593455/wali-kota-tasikmalaya-asn-yang-tambah-libur-lebaran-2023-akan-disanksi?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016593455/wali-kota-tasikmalaya-asn-yang-tambah-libur-lebaran-2023-akan-disanksi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016593455/wali-kota-tasikmalaya-asn-yang-tambah-libur-lebaran-2023-akan-disanksi?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016593455/wali-kota-tasikmalaya-asn-yang-tambah-libur-lebaran-2023-akan-disanksi
# https://www.pikiran-rakyat.com/jawa-barat/pr-016593455/wali-kota-tasikmalaya-asn-yang-tambah-libur-lebaran-2023-akan-disanksi?page=3
#  PIKIRAN RAKYAT-Muhammadiyahtelah menetapkan perayaan Idul Fitri 1 Syawal 1444 Hijriah jatuh pada Jumat, 21 April 2023. Tersaji informasi 14 lokasi penyelenggaraansholat Ieddi KotaTasikmalaya. Masyarakat KotaTasikmalayayang mengikuti aliranMuhammadiyahdapat mencari lokasisholat Iedterdekat dari rumah masing-masing, sebagaimana dirangkumkan dalam artikel ini. Adapun penetapan perayaan Idul Fitri 1444 Hijriah bagi pengikutMuhammadiyahtelah tercantum dalam Maklumat Nomor 1/MLM/1.0/E/2023 Tentang Penetapan Hasil Hisab Ramadhan, Syawal, dan Zulhijjah 1444 Hijriah. Pimpinan PusatMuhammadiyahmenyebutkan, penentuan perayaan Idul Fitri dilakukan dengan merujuk pada hasil hisab alias perhitungan oleh Majelis Tarjih dan Tajdid yang memakai metode hisab hakiki dan berkriteria wujudul-hilal. Baca Juga:Jelang Lebaran 2023, Arus Mudik di Tol Jakarta-Merak Terpantau Ramai Lancar Berikut lokasisholat Ieddi KotaTasikmalayayang berlangsung pada Jumat, 21 April 2023. Lokasi 1: Stadion Wiradadaha Nagarawangi, Kec CihideungImam/khatib: H Arip Somantri, M.Ag Lokasi 1: Masjid Ar-Rohmah.Imam/khatib: Drs H Hasan Asy’ari Lokasi 2: Masjid Al-Arqom.Imam/khatib: Ade Ridwan H S.Ag
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016580044/14-lokasi-sholat-ied-21-april-2023-di-tasikmalaya-lengkap-dengan-nama-imamnya?page=4
#  PIKIRANRAKYAT- Kesal lama tidak diangkut, warga Kampung Sukagalih Kelurahan Talagasari Kecamatan Kawalu KotaTasikmalayanekat membakarsampahyang berada di Tempat Pembuangan Sampah (TPS) Jalan Abdul Muhyi Kawalu KotaTasikmalayapada Senin, 17 April 2023 malam. Sejumlah warga yang di pimpin RW dan RT setempat berinisiatif membakarsampahkarenasampahsemakin hari semakin menumpuk tanpa ada pengangkutan dari dinas terkait. Dengan menggunakan bahan bakar berupa solar, api segera membakarsampahyang meggunung tersebut. Beruntung satu baksampahyang ada diTPStersebut tidak ikut terbakar. Ketua RW 06 Kelurahan Talagasari Kecamatan Kawalu Kota Tasik Yudi (55) mengatakan, warga didaerahnya sudah kesal dengan keberadaansampahyang kian hari kian banyak hingga terlihat menggunung. Sementara petugas pengangkutsampahdari Dinas Lingkungan Hidup (LH) KotaTasikmalayasudah hampir satu minggu lebih tidak melakukan pengangkutan. Baca Juga:Sampah Jadi Potensi Masalah di Masjid Al Jabbar, MUJ Tambah 150 Tong Sampah "Kalau biasanya ada pengangkutan seminggu dua kali pak, tapi entah kenapa sudah seminggu lebih hingga sekarangsampahtidak diangkut-angkut," ujar Yudi pada Selasa, 18 April 2023. Akibatnya kaya Yuyud (sapaan akrab Yudi), kondisiTPSkian penuh dengansampahsehingg bausampahpun kian menyengat. "LokasiTPSnya kan tidak jauh dari pemukiman warga, apalagi sangat dekat dengan lokasi para pedagang termasuk warung nasi sehingga bau dan lalat darisampahmembuat warga tidak nyaman," katanya. Yuyud juga mengatakan, awalnya peruntukanTPStersebut hanya untuk menampungsampahdari warga sekitar. Namun karena letaknya berada dipingir jalan raya, sehingga membuat banyak warga yang dari luar membuangsampahditempat itu. "Kalau peruntukannya hanya untuk warga sini. Tapi karena berada di jalan raya, banyak warga dari mana-mana buangsampahnya di sini. Ada yang naik motor ada yang pake mobil, sudah ga bisa dicegah," jelas Yuyud.
# https://www.pikiran-rakyat.com/jawa-barat/pr-016577458/lebih-dari-seminggu-tak-diangkut-sampah-di-tps-sukagalih-tasikmalaya-nekat-dibakar-warga
# https://www.pikiran-rakyat.com/jawa-barat/pr-016577458/lebih-dari-seminggu-tak-diangkut-sampah-di-tps-sukagalih-tasikmalaya-nekat-dibakar-warga?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016577458/lebih-dari-seminggu-tak-diangkut-sampah-di-tps-sukagalih-tasikmalaya-nekat-dibakar-warga
# https://www.pikiran-rakyat.com/jawa-barat/pr-016577458/lebih-dari-seminggu-tak-diangkut-sampah-di-tps-sukagalih-tasikmalaya-nekat-dibakar-warga?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016577458/lebih-dari-seminggu-tak-diangkut-sampah-di-tps-sukagalih-tasikmalaya-nekat-dibakar-warga
# https://www.pikiran-rakyat.com/jawa-barat/pr-016577458/lebih-dari-seminggu-tak-diangkut-sampah-di-tps-sukagalih-tasikmalaya-nekat-dibakar-warga?page=3
#  PIKIRAN RAKYAT-  Pj Wali KotaTasikmalaya, Cheka Virgowansyah, melakukan pengecekan kesiapan armada arus mudik Lebaran 1444 H di Terminal Indihiang KotaTasikmalaya. Dalam kesempatan tersebut, dia didampingi KapolresTasikmalayakota AKBP Sy Zainal Abidin dan jajaran Dinas Perhubungan KotaTasikmalaya. Cheka Virgowansyah mengatakan, total pergerakan arus mudik untuk musim Lebaran Ramadan 2023 meningkat dari tahun sebelumnya dan diperkirakan sekitar 123.800 juta pemudik di seluruh Indonesia. "Cukup banyak kenaikannya sejak pandemi Covid-19 mulai menurun. Untuk itu kita harus lebih siap dalam mengantisipasi arus mudik," ujar Cheka. Baca Juga:Organda Tasikmalaya Desak Penyesuaian Tarif Angkutan Umum Jelang Lebaran 2023 Dari angka pergerakan arus mudik secara nasional, yang masuk ke sejumlah wilayah di Jawa Barat mencapai sekitar 16 persen. "Dari 16 persen yang masuk ke Jawa Barat tersebut, sekitar 154.000 pemudik masuk wilayahPriangan Timurtermasuk ke KotaTasikmalaya" "Artinya jumlah arus mudik tahun ini kePriangan Timurtermasuk ke Kota Tasik jumlahnya cukup banyak dibanding tahun sebelumnya," ujar Cheka. Salah satu bagian dari kesiapan menghadapi arus mudik tersebut yaitu melakukan pengecekan kesiapan armada angkutan mudik. Menurutnya, ada tiga pengecekan yang harus dilakukan, pertama pengecekan kelaikan jalan armada seperti sistem pemgemudi, sistem pengereman, sistem penerangan, atau lampu-lampu dan yang lainnya. Baca Juga:Angkasa Pura Prediksi 3,9 Juta Pergerakan Penumpang pada Lebaran 2023, Pertumbuhan Capai 34 Persen
# https://www.pikiran-rakyat.com/jawa-barat/pr-016563410/154000-pemudik-lebaran-2023-masuk-wilayah-priangan-timur-termasuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016563410/154000-pemudik-lebaran-2023-masuk-wilayah-priangan-timur-termasuk-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-016563410/154000-pemudik-lebaran-2023-masuk-wilayah-priangan-timur-termasuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016563410/154000-pemudik-lebaran-2023-masuk-wilayah-priangan-timur-termasuk-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-016563410/154000-pemudik-lebaran-2023-masuk-wilayah-priangan-timur-termasuk-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-016563410/154000-pemudik-lebaran-2023-masuk-wilayah-priangan-timur-termasuk-tasikmalaya?page=3
#  PIKIRAN RAKYAT -KepalaBNNKotaTasikmalaya, Iwan Kurniawan Hasyim dicopot usai viral surat permintaan Tunjangan Hari Raya (THR) kePO Bus Budiman. Dia dicopot dari jabatannya oleh Badan Narkotika Nasional (BNN) Provinsi Jawa Barat. Meski begitu, pemeriksaan terhadap Iwan Kurniawan Hasyim itu masih berlangsung, baik oleh penyidikBNNProvinsi Jawa Barat maupun tim Inspektorat dariBNNPusat. Demi kelancaran proses pemeriksaan itu, Iwan Kurniawan Hasyim pun dicopot dari jabatannya. "Menindaklanjuti hal tersebut untuk kelancaran pemeriksaan, PNS yang diduga melakukan pelanggaran disiplin dan kode etik, dibebaskan sementara dari tugas jabatannya sejak yang bersangkutan diperiksa," kata KepalaBNNJawa Barat Arief Ramdhani dalam keterangannya di Bandung, Jawa Barat, Jumat, 14 April 2023. Baca Juga:Tersangka Korupsi Proyek Kereta Api Maling Uang Rakyat demi THR, Rp2,8 M Berhasil Disita Penyidik Dia pun memastikan, pihaknya selalu menekankan agar seluruh pegawai di lingkunganBNNJawa Barat menjalankan kinerja sesuai dengan tugas pokok dan fungsi. Dia berharap, jangan sampai ada pegawai ataupun pimpinan yang menyalahgunakan wewenang atas jabatannya. "Sesuai dengan peraturan yang berlaku dan tidak segan-segan menindak tegas personel yang melakukan pelanggaran," tutur Arief Ramdhani. Oleh karena itu, dia pun meminta seluruh pegawainya guna memberikan pelayanan yang maksimal kepada masyarakat. Badan Narkotika Nasional (BNN) KotaTasikmalaya, Jawa Barat, mengirimkan surat ke perusahaan untuk meminta Tunjangan Hari Raya (THR) atau paket untuk Lebaran 2023. Selebaran dengan kop suratBNNKotaTasikmalayaitu dikirimkan kepada perusahaan angkutan bus. Surat yang ditandatangani dan dicap atas nama KepalaBNNKotaTasikmalayaIwan Kurniawan Hasyim itu tersebar di sejumlah grup WhatsApp wartawan maupun masyarakat KotaTasikmalayapada Selasa, 11 April 2023. Salah seorang wargaTasikmalaya, Fitrian mengaku mendapatkan sebaran informasi tentang suratBNNtersebut dari grup WhatsApp yang berisikan tulisan lembagaBNNmengajukan permohonanTHRatau paket Lebaran untuk anggotaBNNKotaTasikmalaya.
# https://www.pikiran-rakyat.com/nasional/pr-016559842/kepala-bnn-tasikmalaya-dicopot-usai-minta-thr-ke-po-bus-budiman
# https://www.pikiran-rakyat.com/nasional/pr-016559842/kepala-bnn-tasikmalaya-dicopot-usai-minta-thr-ke-po-bus-budiman?page=1
# https://www.pikiran-rakyat.com/nasional/pr-016559842/kepala-bnn-tasikmalaya-dicopot-usai-minta-thr-ke-po-bus-budiman
# ...
# https://www.pikiran-rakyat.com/jawa-barat/pr-01349033/dua-meninggal-akibat-demam-berdarah-di-kota-tasikmalaya-sepanjang-2020
# https://www.pikiran-rakyat.com/jawa-barat/pr-01349033/dua-meninggal-akibat-demam-berdarah-di-kota-tasikmalaya-sepanjang-2020?page=3
# PIKIRAN RAKYAT –BPBD Kota Tasikmalaya ikut terjun membantu pencarian korban longsor di Desa Santanamekar,Kabupaten Tasikmalayayang terjadi pada Jumat, 28 Februari 2020. Sementara itu, Polres Tasikmalaya Kota mengerahkan anjing pelacak dalam pencarian tersebut. Kepala Pelaksana BPBD Kota Tasikmalaya Ucu Anwar mengatakan, ada 12 petugas Satgas BPBD Kota Tasikmalaya yang terlibat dalam pencarian. Hingga Rabu siang, lanjut Ucu, Kepolisian Resort Kota Tasikmalaya Kota mengerahkan pula anjing-anjing pelacak. Baca Juga:Presiden Jokowi Imbau Lindungi Hak Pribadi WNI yang Positif Terinfeksi Virus Corona "AnjingK-9 tiga ekor," ucapnya saat dihububungi, Rabu 4 Maret 2020. Namun, keberadaan korban bernama Didi, 63 tahun asal Kampung Palasari, Desa Santanamekar belum terdeteksi. Hal serupa dikemukakan Kepala KantorSARBandung‎‎ Deden Ridwansah dalam keterangan tertulisnya, Rabu siang. ‎"TimSARGabungan memulai pencarian korban atas nama Didi sejak pukul 08.00 WIB pagi," ucapnya. Di hari itu, TimSARgabungan juga melakukan pencarian dengan membagi para petugas dalam dua SRU (SARunit). ‎ Baca Juga:Ramai Pemberitaan Hoaks Virus Corona, Tommy Kurniawan: Harus Diatasi "SRU 1 melakukan pencarian di bagian atas titik duga korban tertimbun menggunakan 1 unit alkon (alat sedot air) dan mencangkul secara manual dan SRU 2 melakukan pencarian di bagian bawah titik duga korban tertimbun menggunakan 1 unit alkon dan mencangkul secara manual," ucapnya. Kendala cuaca dan tebalnya tanah masih dialami petugas di hari kelima pencarian.
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347015/telusuri-korban-longsor-santamekar-kabupaten-tasikmalaya-anjing-pelacak-dikerahkan
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347015/telusuri-korban-longsor-santamekar-kabupaten-tasikmalaya-anjing-pelacak-dikerahkan?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347015/telusuri-korban-longsor-santamekar-kabupaten-tasikmalaya-anjing-pelacak-dikerahkan
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347015/telusuri-korban-longsor-santamekar-kabupaten-tasikmalaya-anjing-pelacak-dikerahkan?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347015/telusuri-korban-longsor-santamekar-kabupaten-tasikmalaya-anjing-pelacak-dikerahkan
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347015/telusuri-korban-longsor-santamekar-kabupaten-tasikmalaya-anjing-pelacak-dikerahkan?page=3
# PIKIRAN RAKYAT –Longsor terjadi di Kampung Nusalaksana Pamipiran, Kelurahan Leuwiliang, Kecamatan Kawalu,Kota Tasikmalaya. Akibatnya, akses jalan penghubung Leuwiliang-Urug sempat terputus. Kepala Pelaksana Badan Penanggulangan Bencana Daerah (BPBD)Kota TasikmalayaUcu Anwar menuturkan, peristiwa tersebut terjadi Selasa, 3 Maret 2020, pukul 14.35 WIB. Baca Juga:Pikiran Rakyat dan Uninus Kerja Sama Tingkatkan SDM Materiallongsorpun menimbun badan jalan. "Akses jalan dari Leuwiliang ke Urug tertutup," ucap Ucu saat dihubungi, Rabu, 4 Maret 2020. Petugas BPBD dan warg kemudian turun untuk membuka kembali akses penghubung tersebut pada pukul 16-30 WIB. Mereka bahu membahu membersihkan timbunan tanah hingga pukul 22.00 WIB. Terdapat 15 petugas BPBDKota Tasikmalayayang turut serta dalam pengerukan timbunanlongsor. Ucu bahkan ikut serta dalam upaya pembersihan tersebut. Baca Juga:Gandeng Lady Gaga, BLACKPINK Gebrak Kembali Dunia Musik Selain mencangkul dan menggunakan peralatan manual lain, BPBD juga mengerahkan alat berat jenis eksavator untuk pengerukan. Akhirnya, kerja bersama itu membuahkan hasil. Akses jalan kembali normal dan warga bisa melintasinya.
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01347002/longsor-timbun-jalan-penghubung-leuwiliang-urug-kota-tasikmalaya?page=4
# PIKIRAN RAKYAT –Yana Nuryana Sidik, 59 tahun, pegawai negeri sipil asal Kampung Cigantang Hilir, RT 03 RW 01, Kelurahan Cigantang, Kecamatan Mangkubumi tewas setelah sepeda motornya tertabrak truk di Jalan Gubernur Sewaka,Kota Tasikmalaya, Senin, 2 Maret 2020. Peristiwa nahas tersebut bermula saat Yana melintasi jalan itu menggunakan sepedamotorjenis Yamaha Jupiter MX NRKB nomor polisi Z 5947 LK pada pukul 06.00 WIB. Yana melintas dengan membonceng Ai Nurhamidah, 54 tahun. Baca Juga:Intip Fitur Terbaru dari TikTok, Salah Satunya Penggunaan Stiker Buat Video Jadi Lebih Menarik "(Korban) datang dari arah Jalan Babakan Kadu,‎ ketika berbelok ke kanan jalan untuk memutar arah menuju ke arah Cisumur, sesaat di tempat kejadian bagian belakangnya tertabrak oleh kendaraan Light Truck Mitsubishi Colt Diesel (nomor polisi) Z 8635 DG yang dikemudikan oleh Saudara Deni," ucap Kepala Unit Laka Lantas Polres Tasikmalaya Kota Ipda Zezen Zaenal M, SH dalam keterangan tertulisnya, Senin siang. Truk tersebut melaju dari arah Cisumur menuju Linggajaya. Akibatnya, Yana meninggal dan Ai hanya menderita luka ringan. Korban diduga tidak memerhatikan situasi arus lalu lintas sebelum mengubah/memutar arah. Baca Juga:Guru Besar ITB Sri Widiyantoro Jabat Rektor Universitas Kristen Maranatha Sedangkan pengemudi truk diduga menjalankan kendaraanya dengan kecepata tinggi serta tak memperhatikan adanya sepedamotoryang tengah mengubah arah. Kondisi kedua kendaraan yang terlibat kecelakaan tersebut diketahui laik jalan.
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01346276/sepeda-motor-tertabrak-truk-pns-tewas-di-jalan-gubernur-sewaka-kota-tasikmalaya?page=4
# PIKIRAN RAKYAT- Seorang warga terluka dan kritis setelah tertimpa dahanpohonyang patah di kawasanPurbaratu, KotaTasikmalaya, Selasa, 25 Februari 2020, sekira pukul 15.30 WIB. Pohon tersebut patah setelahangin kencangmelanda kawasan tersebut. Kepala Pelaksana Badan Penanggulangan Bencana Daerah (BPBD) KotaTasikmalayaUcu Anwar menuturkan, peristiwa nahas itu bermula saat warga bernama Dani, 35 tahun, pulang selepas mencari ikan di sungai dan sawah pada sekira pukul 15.30 WIB. Baca Juga:Sudah Tua dan Keropos, Ratusan Pohon di Bandung Utara Rawan Tumbang Warga Bojongnangka, Kelurahan Sukamenak tersebut pulang ke rumah dengan menggunakan sepeda motor. "Tiba-tibaangin kencangdan mematahkan dahan besar lalu menimpanya," kata Ucu saat dihubungi. Korban pun terkapar di jalan kawasanPurbaratudengan darah mengucur dari kepalanya. Warga segera berdatangan untuk menolong korban yang tertimpapohonjenis trembesi tersebut. Petugas BPBD, lanjut Ucu, ikut turun tangan membantu. "Kami mengantar dan memfasilitasi penanganan medis oleh pihak RSUD (Rumah Sakit Umum Daerah Dokter Soekardjo)," ujarnya. Baca Juga:Jelang Kick-Off Liga 1 2020, Pelatih Persib Pandang Lini Pertahanannya Sudah Stabil Akibat peristiwa itu, kondisi korban kritis dan dirawat di ruang instalasi gawat darurat (IGD). "Dan harus di CT scan," kata Ucu. Selain bagian kepala, korban mengalami robek bibir serta mendapat jahitan luar dalam. Ucu menambahkan,pohontrembesi memang relatif rapuh dan mudah patah. Peristiwapohontumbangatau dahan patah bukanlah pertama kali terjadi di wilayah KotaTasikmalaya. Bahkan seorang warga tewas setelah tertimpapohontumbangdi Kompleks Olah Raga Dadaha pada awal November 2019.
# https://www.pikiran-rakyat.com/jawa-barat/pr-01344076/pengendara-motor-kritis-setelah-tertimpa-dahan-pohon-yang-patah-di-purbaratu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01344076/pengendara-motor-kritis-setelah-tertimpa-dahan-pohon-yang-patah-di-purbaratu-kota-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-01344076/pengendara-motor-kritis-setelah-tertimpa-dahan-pohon-yang-patah-di-purbaratu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01344076/pengendara-motor-kritis-setelah-tertimpa-dahan-pohon-yang-patah-di-purbaratu-kota-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-01344076/pengendara-motor-kritis-setelah-tertimpa-dahan-pohon-yang-patah-di-purbaratu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01344076/pengendara-motor-kritis-setelah-tertimpa-dahan-pohon-yang-patah-di-purbaratu-kota-tasikmalaya?page=3
#
# https://www.pikiran-rakyat.com/nasional/pr-01339655/rumah-ambruk-satu-orang-terluka-di-cipedes-kota-tasikmalaya
# https://www.pikiran-rakyat.com/nasional/pr-01339655/rumah-ambruk-satu-orang-terluka-di-cipedes-kota-tasikmalaya?page=1
# PIKIRAN RAKYAT –Jalan lempeng kecil itu terimpit kios-kios pedagang yang berderet di kanan kirinya. Lalu lalang kendaraan berpadu dengan hiruk pikuk aktivitas jual beli pedagang pembeli menjadi pemandangan jamak saban hari di sana. Terletak di Kelurahan Cilembang, Kecamatan Cihideung, Kota Tasimalaya, warga mengenal tempat tersebut dengan namaPasarRel. Baca Juga:Program Smart City Kota Cirebon Tak Berjalan Mulus, Sejumlah Aplikasi Tak Dimanfaatkan oleh Warga Ya, kegiatan jual beli dan keberadaan kios-kios sudah menjadi bukti lokasi itu memang pasar. Tetapi kenapa ada istilahrelyang dilekatkan sebagai identitas atau nama pasar? Kalau memang betul ada jalur kereta di mana jejak-jejaknya? Pertanyan itu membawa Pikiran-Rakyat.com menyambangiPasarRel, Rabu, 12 Februari 2020. Baca Juga:Coldiac Rilis Single No Make Up, Kolaborasi dengan Musisi Malaysia NYK Ternyata, jalan lurus diapit deretan kios itu sudah tak menyisakan batang-batang besi yang menjadi landasan jalur kereta api. Meskipun jejak jalur kereta telah lenyap, kisahPasarRel masih terpatri dalam diri warga dan pedagang yang bermukim dan berjualan di tempat tersebut.
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas?page=4
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas?page=5
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas
# https://www.pikiran-rakyat.com/jawa-barat/pr-01339599/kisah-pasar-rel-kota-tasikmalaya-dan-deru-si-kuik-yang-melintas?page=6
# PIKIRAN RAKYAT –Jasad pria ditemukan di sebuahkolamdi Kampung Cibuyut, RT 05 RW 01, Kelurahan Karanganyar, KecamatanKawalu,Kota Tasikmalaya. Musabab kematiannya masih dalam proses penyelidikan. Penemuanmayatterkuak saat petugas Badan Penanggulangan Bencana Daerah (BPBD)Kota Tasikmalayamenerima laporan Babinsa. Baca Juga:Boy Band Smash Gandeng Oomleo sang Pionir Karaoke Massal dalam Single Barunya Dalam laporan,jasadditemukan pada Sabtu, 8 Februari 2020, pukul 18.00 WIB. Dari hasil penelusuran satu jam kemudian,jasadkorban berada dikolammilik warga bernama Herdi di kampung tersebut. Korban diketahui bernama Supyan, 55 tahun, seorang buruh asal Kampung Cijerah RT 04 RW 03, Kelurahan Karanganyar, KecamatanKawalu. Baca Juga:1.000 Peserta Ikuti 5K Colour Run yang Digelar untuk Peringati Hari Kanker Sedunia "Pukul 19.30 WIB Korban dievakuasi oleh tim BPBDKota Tasikmalayadan Polres Tasikmalaya Kota menuju RSUD Dokter SoekardjoKota Tasikmalaya," kata Kepala Pelaksana BPBDKota TasikmalayaUcu Anwar dalam keterangan tertulisnya, Sabtu malam. Musabab kematian korban pun dalam pemeriksaan tim dokter.
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya?page=1
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya?page=2
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya?page=3
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya
# https://www.pikiran-rakyat.com/jawa-barat/pr-01338553/mayat-pria-ditemukan-di-kolam-warga-kawalu-kota-tasikmalaya?page=4
#                                                  url  \
# 0  https://www.pikiran-rakyat.com/jawa-barat/pr-0...
# 1  https://www.pikiran-rakyat.com/jawa-barat/pr-0...
# 2  https://www.pikiran-rakyat.com/jawa-barat/pr-0...
# 3  https://www.pikiran-rakyat.com/jawa-barat/pr-0...
# 4  https://www.pikiran-rakyat.com/jawa-barat/pr-0...
#
#                                                title                date  \
# 0  Matahari Mega Mall Kota Tasikmalaya Kebakaran,... 2023-06-09 16:07:00
# 1  Polisi Tangkap Pria yang Mencabuli Keponakanny... 2023-06-02 20:00:00
# 2  Isi Rekaman Mediasi Siswa SMA Tasikmalaya deng... 2023-05-22 16:36:00
# 3  Jalan Rusak, Warga Keluhkan Genangan Air di Pa... 2023-05-16 18:11:00
# 4  Kota Tasikmalaya Masuk 10 Besar Pencapaian Vak... 2023-05-15 07:00:00
#
#                                              content
# 0   PIKIRAN RAKYAT–Matahari Mega MallKotaTasikmal...
# 1   PIKIRAN RAKYAT- Kepolisian Resor KotaTasikmal...
# 2  PIKIRAN RAKYAT -Komisi Perlindungan Anak Indon...
# 3   PIKIRAN RAKYAT- Kondisi sejumlah ruasjalandi ...
# 4   PIKIRANRAKYAT- Angka cakupan pencapaian pelak...

# %%
df_pr.shape
# Out:
# (400, 4)

# %%
df_pr.to_excel("data/berita_pr.xlsx", index=False)

# %% [markdown]
# ## Text Cleaning

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/peminumyakult/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re, string, unicodedata  #modul regular expression
import nltk
from nltk import word_tokenize, sent_tokenize  #Paket ini membagi teks input menjadi kata-kata.,                                  
from nltk.corpus import stopwords

# %%
#preprocessing
def removeStopword(str):
    stop_words = set(stopwords.words('indonesian'))
    word_tokens = word_tokenize(str)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return ' '.join(filtered_sentence)
#remove sentence which contains only one word
def removeSentence(str): 
    word = str.split()
    wordCount = len(word)
    if(wordCount<=1):
        str = ''
    
    return str
def cleaning(str):
    #remove non-ascii
    str = unicodedata.normalize('NFKD', str).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    #remove URLs
    str = re.sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', '', str)
    #remove punctuations
    str = re.sub(r'[^\w]|_',' ',str)
    #remove digit from string
    str = re.sub("\S*\d\S*", "", str).strip()
    #remove digit or numbers
    str = re.sub(r"\b\d+\b", " ", str)
    #to lowercase
    str = str.lower()
    #Remove additional white spaces
    str = re.sub('[\s]+', ' ', str)
       
    return str
def preprocessing(str):
    str = removeSentence(str)
    str = cleaning(str)
    str = removeStopword(str)
    
    return str

# %%
#test the code
sentences = ["dimana lokasi kuliner tasikmalaya yang murah","alamat tasik dimana sih, yang enak","s"]
for st in sentences:
    r = preprocessing(st)
    print(r)
# Out:
# dimana lokasi kuliner murah
# alamat dimana sih enak

# %%
# data dari detik.com
txt_detik = df['summary'].apply(preprocessing)

# Save the preprocessed data to a new CSV file
txt_detik.to_csv('data/detik-clean-data.csv', index=False)

# %%
txt_pr = df_pr['content'].apply(preprocessing)

# %%
# Fungsi untuk menghapus frasa 'pikiran rakyat' dan 'pikiranrakyat'
def hapus_frasa(text):
    text = text.replace('pikiran rakyat', '').replace('pikiranrakyat', '')
    return text

# %%
# Menghapus frasa 'pikiran rakyat' dan 'pikiranrakyat' dari setiap teks dalam daftar
txt_pr_clean = txt_pr.apply(hapus_frasa)

# %%
txt_pr
# Out:
# 0      pikiran rakyatmatahari mega mallkotatasikmalay...
# 1      pikiran rakyat kepolisian resor kotatasikmalay...
# 2      pikiran rakyat komisi perlindungan anak indone...
# 3      pikiran rakyat kondisi ruasjalandi wilayah kot...
# 4      pikiranrakyat angka cakupan pencapaian pelaksa...
#                              ...
# 395    pikiran rakyat yana nuryana sidik pegawai nege...
# 396    pikiran rakyat warga terluka kritis tertimpa d...
# 397
# 398    pikiran rakyat jalan lempeng terimpit kios kio...
# 399    pikiran rakyat jasad pria ditemukan sebuahkola...
# Name: content, Length: 400, dtype: object

# %%
txt_pr_clean
# Out:
# 0      matahari mega mallkotatasikmalayamengalamikeba...
# 1       kepolisian resor kotatasikmalayaberhasil mena...
# 2       komisi perlindungan anak indonesia daerah kpa...
# 3       kondisi ruasjalandi wilayah kotatasikmalayasu...
# 4       angka cakupan pencapaian pelaksanaanvaksinpol...
#                              ...
# 395     yana nuryana sidik pegawai negeri sipil kampu...
# 396     warga terluka kritis tertimpa dahanpohonyang ...
# 397
# 398     jalan lempeng terimpit kios kios pedagang ber...
# 399     jasad pria ditemukan sebuahkolamdi kampung ci...
# Name: content, Length: 400, dtype: object

# %%
txt_pr_clean.to_csv('data/pr-clean-data.csv', index=False)
